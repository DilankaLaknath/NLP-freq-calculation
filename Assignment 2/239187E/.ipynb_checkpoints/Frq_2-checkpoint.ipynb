# %%
import csv

# Create a dictionary to store the word frequencies
word_freq = {}

# %%
# Read in the text file
with open('28757_Tamil.txt', 'r', encoding='utf-8') as f:
    for line in f:
        # Split the line into words, removing leading/trailing whitespace and punctuation
        words = [word.strip(' .') for word in line.split()]
        # Add each word to the dictionary or increment its count
        for word in words:
            word_freq[word] = word_freq.get(word, 0) + 1

# %%
word_freq
# Out:
# {'அமைச்சின்': 237,
#  'பணிகளை': 29,
#  'முன்னெடுப்பதற்கு': 2,
#  'கௌர': 2,
#  'அமைச்சர்': 103,
#  'வாசுதேவ': 9,
#  'நாணாயக்கார': 6,
#  'அவர்களுக்கு': 43,
#  'தத்துவம்': 4,
#  'வழங்கப்பட்டதுடன்': 2,
#  'திருமதி': 106,
#  'எம்': 229,
#  '': 13451,
#  'எஸ்': 156,
#  'விக்கிரமசிங்க': 5,
#  'செயலாளராக': 1,
#  'செயலாற்றுகிறார்': 1,
#  'தேசிய': 332,
#  'மொழிகள்': 98,
#  'மற்றும்': 2030,
#  'சமூக': 157,
#  'ஒருமைப்பாட்டு': 54,
#  'அதிகாரங்கள்': 4,
#  'செயற்பாடுகள்': 22,
#  '\uf0b7': 20,
#  ',': 5332,
#  'ஒருமைப்பாடு': 10,
#  'தொடர்பான': 211,
#  'கொள்கைகள்': 8,
#  'நிகழ்ச்சித்': 69,
#  'திட்டங்களையும்': 3,
#  'கருத்திட்டங்களையும்': 1,
#  'வகுத்தமைத்தல்': 2,
#  'மொழிக்': 34,
#  'கொள்கையை': 3,
#  'செயற்படுத்துதலுடன்': 1,
#  'அலுவல்கள்': 85,
#  'ஒருமைப்பாடும்': 1,
#  'இனங்களுடனான': 1,
#  'அலுவல்களும்': 3,
#  ';': 1150,
#  'மனித': 24,
#  'உரிமைகளை': 2,
#  'பாதுகாப்பதற்கு': 4,
#  'அமைவான': 3,
#  'கொள்கைக்கு': 9,
#  'அமைவாக': 42,
#  'அரசகரும': 65,
#  'கொள்கை': 30,
#  'நடைமுறைப்படுத்துவதற்கு': 9,
#  'சிபாரிசுகளை': 4,
#  'நடைமுறைப்படுத்தல்': 23,
#  'மும்மொழி': 5,
#  'இலங்கைக்கான': 1,
#  'பத்தாண்டு': 2,
#  'திட்டத்திற்கு': 8,
#  'விடயப்': 5,
#  'பரப்புக்கு': 2,
#  'அரச': 335,
#  'உத்தியோகத்தர்கள்': 75,
#  'மொழித்': 11,
#  'தேர்ச்சி': 19,
#  'பெற்றுக்': 454,
#  'கொள்வதற்கு': 42,
#  'முன்வைக்கப்பட்டுள்ள': 12,
#  'உத்தியோகத்தர்': 720,
#  'குழு': 67,
#  'அறிக்கை': 143,
#  '2014': 66,
#  'ஆம்': 1548,
#  'ஆண்டில்': 95,
#  'மொழிப்': 7,
#  'பிரிவானது': 2,
#  '4': 116,
#  'இலக்குகளை': 2,
#  'மையமாகக்': 2,
#  'கொண்டு': 119,
#  'அதன்': 164,
#  'நடவடிக்கைகளை': 63,
#  'முன்னெடுத்துள்ளது': 1,
#  'அதற்கேற்ப': 23,
#  'இதுவரையும்': 1,
#  'மேல்': 31,
#  'மத்திய': 126,
#  'தென்': 12,
#  'கிழக்கு': 29,
#  'மாகாணங்களை': 3,
#  'முன்னிலைப்படுத்தி': 2,
#  'பொலிஸ்': 35,
#  'நிலையங்களில்': 8,
#  'பிரதான': 84,
#  'உத்தியோகத்தர்களுக்காக': 6,
#  'இச்': 21,
#  'செயலமர்வு': 16,
#  'ஒழுங்குசெய்யப்பட்டது': 1,
#  'மூலம்': 455,
#  'அந்த': 192,
#  'பிரதேசங்களில்': 7,
#  'நடைமுறைப்படுத்தலின்': 2,
#  'முரண்பாடுகளை': 3,
#  'கண்டறிந்து': 2,
#  'அது': 144,
#  'தொடர்பாக': 511,
#  'தேவையான': 222,
#  'நடவடிக்கைகள்': 132,
#  'எடுப்பதற்கு': 3,
#  'அமைச்சு': 186,
#  'முன்வந்துள்ளது': 2,
#  '1.2': 1,
#  'இரு': 46,
#  'மொழி': 105,
#  'பிரதேச': 361,
#  'செயலகப்': 7,
#  'பிரிவுகள்': 23,
#  'ஏனைய': 197,
#  'செயலாளர்': 621,
#  'காரியாலயங்களில்': 5,
#  'மீளாய்வு': 14,
#  'நிகழ்ச்சிகளை': 35,
#  'நடாத்துதல்': 6,
#  'நடைமுறைப்படுத்தும்': 15,
#  'போது': 262,
#  'ஏற்படும்': 26,
#  'களைந்து': 1,
#  'முன்னேற்றுவதனை': 1,
#  'நோக்கமாகக்': 4,
#  'ஆரம்பிக்கப்பட்ட': 26,
#  'நிகழ்ச்சித்திட்டமாகும்': 1,
#  'விமர்சன': 3,
#  'செயலமர்வுகள்': 7,
#  '24': 29,
#  'நடைமுறைப்படுத்த': 20,
#  'திட்டமிடப்பட்டுள்ளது': 9,
#  '2014.08.21': 1,
#  'திகதி': 750,
#  'மதிப்பீட்டுக்': 9,
#  'வத்தளை': 1,
#  'செயலகத்துக்கு': 3,
#  'உட்பட்ட': 13,
#  '11': 78,
#  'நிறுவனங்களிலும்': 3,
#  '2014.09.19': 1,
#  '13': 39,
#  'நீர்கொழும்பு': 1,
#  'நிறுவனங்கள்': 52,
#  'இலும்': 3,
#  'மேற்பார்வை': 14,
#  'செய்யப்பட்டன': 10,
#  'மேலும்': 129,
#  '2014.10.31': 2,
#  '2014.11.10.17.21.24': 1,
#  'திகதிகளில்': 20,
#  'களுத்தறை': 1,
#  'ஹம்பாந்தோட்டை': 2,
#  'மாவட்டங்களின்': 3,
#  '55': 8,
#  'ல்': 9,
#  'செய்யப்பட்டது': 30,
#  'பிற்பாடு': 1,
#  '2014.11': 4,
#  '28ஆம்': 3,
#  'மாவனெல்ல': 1,
#  '7லிலும்': 1,
#  '2014.12.05': 1,
#  'கேகாலை': 8,
#  'மாவட்டத்திற்கு': 4,
#  '11லும்': 1,
#  'இடம்பெற்றன': 2,
#  'ரீதியான': 15,
#  'மேற்பார்வைக்கு': 2,
#  'தயாரிக்கப்பட்டுள்ளது': 5,
#  'இதற்கேற்ப': 3,
#  '2013': 53,
#  'சப்ரகமுவ': 5,
#  'மாகாண': 199,
#  'வருடத்தில்': 24,
#  'வடமேல்': 8,
#  'ஒழுங்குபடுத்தியிருந்தது': 1,
#  'நடைமுறைப்படுத்துவது': 2,
#  'உத்தியோகத்தர்களை': 16,
#  'தெளிவுபடுத்தல்': 2,
#  '2014.10.10': 3,
#  'பதுளை': 9,
#  'மாவட்டத்தில்': 57,
#  'பசறை': 1,
#  'முகாமைத்துவ': 86,
#  'நிறுவனத்தில்': 13,
#  'ஊவா': 8,
#  'மாகாணத்தில்': 15,
#  'சார்பாக': 98,
#  'வெற்றிகரமாக': 20,
#  'நடைபெற்றது': 13,
#  'அமைச்சுக்கு': 16,
#  'நிறுவனங்களின்': 32,
#  'பணிகள்': 76,
#  'சேவைகள்': 129,
#  'தொடர்பாகவும்': 16,
#  'அந்தந்த': 21,
#  'எதிர்நோக்கும்': 3,
#  'முரண்பாடுகள்': 5,
#  'கலந்துரையாடப்பட்டன': 1,
#  '1.5': 4,
#  'தேசத்திற்கு': 10,
#  'மகுடம்': 13,
#  'கண்காட்சிக்கு': 7,
#  'இடம்பெற்ற': 8,
#  'பாடசாலை': 179,
#  'அடிப்படையாகும்': 1,
#  '2014/2015': 2,
#  'அபிவிருத்தி': 330,
#  'நடைபெற்ற': 38,
#  'கீழே': 43,
#  'காண்க': 3,
#  'மாவட்ட': 208,
#  'வாசிகசாலைகளுக்கு': 1,
#  'புத்தகங்கள்': 4,
#  'வழங்கப்பட்டன': 6,
#  'அத்துடன்': 21,
#  'அகராதிகள்': 1,
#  '750': 5,
#  'கொள்வனவு': 74,
#  'ஆண்டுக்கு': 5,
#  'வெளியீடுகள்': 5,
#  'வெளியிடப்படவிருந்தன': 1,
#  'அதில்': 47,
#  '2': 356,
#  'வெளியிடப்பட்டு': 1,
#  'முடிவுற்றுள்ளது': 1,
#  '2.2': 5,
#  'செயலகங்கள்': 5,
#  'உதவு': 4,
#  'நிலையங்கள்': 38,
#  'உருவாக்குதல்': 11,
#  'நிறுவனங்களில்': 13,
#  'பொது': 161,
#  'மக்கள்': 73,
#  'தாம்': 7,
#  'விரும்பிய': 4,
#  'மொழியில்': 7,
#  'சேவையை': 23,
#  'பெற்றுக்கொள்ளும்': 10,
#  'வாய்பை': 1,
#  'இலகுபடுத்துவதை': 1,
#  'நோக்கமாக': 4,
#  '2012': 65,
#  'தொடக்கம்': 30,
#  'நிலையம்': 78,
#  'ஆரம்பிக்கப்பட்டது': 12,
#  'இவ்விடயத்தில்': 1,
#  'இன்னுமொரு': 1,
#  'படி': 121,
#  'மேலாக': 10,
#  'காரியாலயங்கள்': 2,
#  '19': 14,
#  'இல்': 35,
#  'அமைத்து': 6,
#  'பூர்த்தி': 66,
#  'செய்யப்பட்டுள்ளது': 35,
#  '6': 60,
#  '8': 53,
#  'அமைக்க': 9,
#  'தீர்மாணிக்கப்பட்டது': 1,
#  '2.3': 4,
#  'சேவை': 260,
#  'இருமொழியாக்கல்': 1,
#  'நடைமுறைப்படுத்தலுக்கு': 2,
#  'வலுப்படுத்தும்': 1,
#  'முகமாக': 9,
#  '2009.11.25': 1,
#  'நிர்வாக': 62,
#  'சுற்றறிக்கை': 25,
#  'இலக்கம்': 467,
#  '18/2009': 1,
#  'அரசமொழிக்': 1,
#  'பொறுப்பு': 24,
#  'அளிக்கப்பட்டுள்ளது': 4,
#  'அனைத்து': 153,
#  'மத்தியில்': 12,
#  'தமது': 51,
#  'பூரண': 11,
#  'வழங்கப்பட்டுள்ளது': 13,
#  'இதனூடாக': 4,
#  'சேவையில்': 89,
#  'சிறந்த': 79,
#  'நிர்வாகத்துக்கான': 1,
#  'திட்டம்': 66,
#  'ஒழுங்கமைக்கப்பட்டுள்ளது': 1,
#  '2014.01.21': 1,
#  '01/2014': 1,
#  'அடையப்பட': 1,
#  'வேண்டிய': 181,
#  'மொழித்தேர்ச்சி': 1,
#  'விடயங்கள்': 73,
#  'உள்ளடங்கப்பட்டுள்ளதுடன்': 1,
#  'சிங்களம்': 30,
#  'தமிழ்': 92,
#  'மொழிகளை': 3,
#  'அறிந்து': 24,
#  'கொள்ளல்': 114,
#  'வழங்குவதன்': 8,
#  'முக்கியத்துவம்': 13,
#  'தெளிவுபடுத்தப்பட்டது': 1,
#  'உள்ள': 156,
#  'பொறுப்புகள்': 5,
#  'கூட்டம்': 26,
#  '2014.09.01': 1,
#  'அமைச்சுகளின்': 2,
#  'செயலாளர்களின்': 2,
#  'பங்கேற்புடன்': 1,
#  'இடம்பெற்றது': 3,
#  'விசேட': 235,
#  'அதிதியாக': 1,
#  'கௌரவ': 72,
#  'கலந்து': 38,
#  'கொண்டார்': 2,
#  'ஒருமைப்பாட்டுக்': 2,
#  'இன': 3,
#  'ஒற்றுமை': 2,
#  'முன்வைக்கப்பட்டது': 3,
#  'செயலாளர்கள்': 35,
#  '40': 25,
#  'பேர்': 17,
#  'உட்பட': 29,
#  '128': 2,
#  'கொண்டனர்': 4,
#  '3': 186,
#  'செயற்பாட்டு': 12,
#  'நிகழ்ச்சி': 130,
#  '3.1': 3,
#  'மொழிச்சங்கங்கள்': 4,
#  'மொழிகளால்': 1,
#  'இதயபூர்வமாக': 1,
#  'இணைந்த': 57,
#  'சமாதானம்': 4,
#  'மிக்க': 10,
#  'ஒரே': 38,
#  'இலங்கை': 301,
#  'தேசத்தை': 1,
#  'கட்டியெழுப்புவதை': 1,
#  'அரசகருமமொழிக்': 1,
#  'நடைமுறைப்படுத்துவதன்': 1,
#  'முக்கியத்துவத்தை': 2,
#  'பொதுமக்கள்': 13,
#  'செல்வதற்கான': 15,
#  'நிகழ்ச்சியாக': 2,
#  'மொழிச்சங்க': 14,
#  'திட்டத்தை': 20,
#  'குறிப்பிடலாம்': 2,
#  'இந்நிகழ்ச்சி': 1,
#  'இருந்து': 69,
#  'ஆரம்பிக்கப்பட்டுள்ளதுடன்': 1,
#  'இதுவரை': 34,
#  '2428': 1,
#  'பூராவும்': 3,
#  'ஏற்படுத்தப்பட்டுள்ளன': 2,
#  'கல்வி': 386,
#  'பயிற்சி': 135,
#  'நிறுவனம்': 95,
#  'நிதி': 281,
#  'அமைச்சுகளை': 1,
#  'பிரதிநிதித்துவப்படுத்தி': 1,
#  'கலந்துக்கொண்டனர்': 1,
#  'மொழிச்சங்கங்களில்': 1,
#  'ஆரம்பம்': 5,
#  'எதிர்கால': 28,
#  'கலந்துரையாடப்பட்டது': 4,
#  'செயற்பாடு': 13,
#  'நிகழ்ச்சிகள்': 70,
#  'கீழ்': 638,
#  'மாநாடுகள்': 1,
#  '2014.05': 5,
#  '10ஆம்': 18,
#  'குருவிட': 1,
#  'இரத்தினபுரி': 15,
#  '27ஆம்': 1,
#  'ஓபநாயக': 1,
#  'கொடகவெல': 1,
#  '30ஆம்': 5,
#  'பலாங்கொடை': 1,
#  'ஆகிய': 93,
#  'செயலக': 19,
#  '2014.07.11': 1,
#  'தனமல்வில': 4,
#  'காரியாலயத்தில்': 36,
#  'மாநாடு': 9,
#  'புத்தள': 3,
#  'வல்லவாய': 1,
#  'போன்ற': 46,
#  'பிரதேசங்களின்': 1,
#  'உறுப்பினர்கள்': 15,
#  'கலந்துகொண்டனர்': 2,
#  'மொழிச்சங்கம்': 1,
#  'முன்னேற்ற': 35,
#  '2014.09.12': 1,
#  'இடம்': 48,
#  'பெற்றது': 9,
#  '2014.10.14': 1,
#  'எம்பிலிபிடிய': 1,
#  '70': 12,
#  'நடவடிக்கை': 262,
#  'மூலமாக': 27,
#  'கொள்ளப்பட்ட': 16,
#  'விடயங்களும்': 3,
#  'செய்யப்பட்டு': 22,
#  'நிலையத்தில்': 21,
#  'ஒழுங்கமைப்பதற்கு': 1,
#  'உபயோகிக்கப்படவுள்ளது': 1,
#  '3.3': 3,
#  'ஒருமைப்பாட்டை': 3,
#  'மேம்படுத்துவதற்கு': 2,
#  'மொழிச்சங்கள்': 1,
#  'முன்வைக்கப்படும்': 1,
#  'நிகழ்சித்திட்டங்களுக்கு': 1,
#  'நிதியுதவி': 13,
#  'வழங்குதல்': 92,
#  'இந்த': 324,
#  'நோக்கங்களை': 2,
#  'பூராகவும்': 4,
#  'நிகழ்ச்சித்திட்டம்': 18,
#  'முன்னெடுக்கப்படுகின்றது': 1,
#  'இரண்டாம்': 105,
#  'கட்ட': 7,
#  '15': 50,
#  'செயற்பாட்டுத்திட்டங்களுக்கான': 1,
#  'வழங்கப்பட்டது': 11,
#  'யூலை': 14,
#  'மாதம்': 222,
#  '26க்கான': 1,
#  'கொழும்பு': 41,
#  'மாவட்டங்களுக்கான': 1,
#  'நிகழ்ச்சித்திட்டங்களுக்கான': 1,
#  'சிறுகதை': 1,
#  '10': 111,
#  'தெரிவு': 93,
#  'அனுப்பப்பட்டுள்ளது': 8,
#  'ஹெஜ்ஜி': 1,
#  'மாலய': 1,
#  'எனும்': 34,
#  'சிறுவர்': 81,
#  'நாவலின்': 4,
#  'பெயர்ப்பு': 6,
#  'கிட்டியும்': 1,
#  'கழுத்து': 1,
#  'மணிமாலையும்': 1,
#  'என': 93,
#  '1000': 8,
#  'பிரதிகளும்': 1,
#  'கோழி': 3,
#  'அம்மாவும்': 1,
#  'மயில்': 1,
#  'குஞ்சுகளும்': 1,
#  'சிங்கள': 37,
#  'கிகிலி': 1,
#  'அம்மா': 1,
#  'சஹ': 2,
#  'மொணரா': 1,
#  'பெடவ்': 1,
#  'பிரதிகள்': 53,
#  'பதிப்பிக்கப்பட்டது': 1,
#  'ஆண்': 10,
#  'பெண்': 23,
#  'பால்': 8,
#  'நிலை': 65,
#  'சமத்துவம்': 1,
#  'விழிப்புணர்வூட்டும்': 5,
#  'ஊடாக': 116,
#  'மேம்பாட்டு': 11,
#  'உதவியாளர்': 56,
#  'இணைப்பாளர்': 3,
#  'உதவுனர்களுக்கு': 1,
#  'அறிவூட்டும்': 17,
#  '02': 212,
#  '2014.09.18': 1,
#  'அங்கு': 9,
#  'பேச்சுத்திறமை': 1,
#  'வெளிப்படுத்தல்': 3,
#  'முன்': 121,
#  'வைத்தல்': 35,
#  'நடைமுறை': 23,
#  'சார்ந்த': 17,
#  'வழங்கப்பட்ட': 78,
#  'செயற்படுத்தப்படும்': 2,
#  'நிகழ்ச்சிகளுக்கு': 7,
#  'உள்வாங்கப்படுவர்': 1,
#  '2014.11.10': 3,
#  'புத்தி': 1,
#  'ஜீவிகள்': 1,
#  'குழுக்': 18,
#  'இதற்கான': 7,
#  'தொழில்': 93,
#  'நுட்ப': 7,
#  'நிதியுதவிகள்': 2,
#  'கனேடிய': 1,
#  'நிதியுதவியின்': 2,
#  'இயங்கும்': 10,
#  'திட்டத்தினால்': 1,
#  'வழிகாட்டிக்': 1,
#  'கைநூலின்': 1,
#  '3000': 2,
#  'பதிப்பிக்கப்பட்டுள்ளது': 1,
#  'அவசியமான': 7,
#  'முறையான': 19,
#  'திட்டங்கள்': 28,
#  'உள்வாங்கப்படுவதன்': 1,
#  'மக்களுக்கு': 27,
#  'சமமான': 22,
#  'வாய்ப்பினை': 3,
#  'வழங்குவதற்கான': 16,
#  'வழங்குவதுடன்': 4,
#  'மக்களின்': 13,
#  'நிதியானது': 1,
#  'வகையில்': 86,
#  'பாவிப்பதற்கான': 1,
#  'வாய்ப்பு': 15,
#  'ஏற்படுகின்றது': 1,
#  'கருத்தை': 1,
#  'முதனிலைப்படுத்தி': 1,
#  'ஆண்டு': 151,
#  'வழித்தட': 1,
#  'அமைச்சுகளுக்கிடையில்': 1,
#  'உள்நாட்டளுவல்கள்': 1,
#  'தொலைத்தொடர்பு': 1,
#  'தகவல்': 110,
#  'தொழில்நுட்ப': 48,
#  'சுகாதார': 82,
#  'நீதி': 31,
#  'இளைஞர்': 38,
#  'விவகார': 20,
#  'திறன்': 9,
#  'வகிக்கின்றது': 1,
#  'நிறுவனங்களான': 3,
#  'திணைக்களம்': 124,
#  'ஆணைக்குழு': 32,
#  'மொழிக்கல்வி': 2,
#  'இவ்': 28,
#  'ஐந்தாண்டு': 2,
#  'செயற்திட்டத்தை': 1,
#  'ஒழுங்கமைத்து': 2,
#  'முடித்துள்ளது': 1,
#  '2012ஆம்': 4,
#  '2013ஆம்': 2,
#  'வரை': 187,
#  'இலங்கையில்': 79,
#  'பல்வேறுபட்ட': 6,
#  'பிரதிநிதிப்படுத்துவதன்': 1,
#  'புதிய': 160,
#  'புத்தாக்க': 9,
#  'மாதிரிகள்': 1,
#  '14': 60,
#  'இது': 103,
#  'ஏற்படுத்தப்பட்டுள்ளது': 2,
#  'அத்தோடு': 11,
#  'மாதிரி': 30,
#  'பிரிவுகளில்': 22,
#  'அமைந்துள்ள': 52,
#  'நிறுவனங்களுக்கு': 10,
#  'விரிவுபடுத்துவதை': 1,
#  'ஆசிய': 3,
#  'மன்றத்தின்': 3,
#  'அனுசரனையின்': 1,
#  'முன்னெடுக்க': 2,
#  '4.5': 1,
#  'ஸ்தாபித்தல்': 5,
#  'நிறுவனங்களினது': 1,
#  'சேவைகளை': 20,
#  'மட்டத்தில்': 40,
#  'விரிவு': 1,
#  'படுத்துவதை': 1,
#  'கொண்ட': 172,
#  'நிகழ்ச்சித்திட்டமாக': 1,
#  'இம்': 5,
#  'அமைக்கப்பட்டுள்ளதை': 1,
#  'பயிற்சிக்காக': 2,
#  'ஆசிரியர்கள்': 37,
#  'தனியார்': 51,
#  'செய்யப்பட்ட': 182,
#  '31': 20,
#  'நிறைவின்': 1,
#  'பின்னர்': 130,
#  'இவர்கள்': 12,
#  'வட': 16,
#  'வகுப்புகளுக்கு': 5,
#  'கற்பித்தலுக்காக': 1,
#  'இணைத்துக்': 8,
#  'கொள்ளப்படுவர்': 1,
#  '2014.11.03': 1,
#  'வவுனியா': 4,
#  'செயலகத்தில்': 6,
#  'கஹடஸ்திலிய': 1,
#  'செயற்பாட்டுக்': 2,
#  'முன்வைக்கப்பட்ட': 16,
#  'திட்டத்துக்காக': 3,
#  'கருத்திட்ட': 23,
#  'ரூ': 83,
#  '140': 2,
#  '000': 17,
#  'செயற்பாட்டின்': 3,
#  'ஏற்படுத்தப்பட்ட': 2,
#  'இணைப்பு': 79,
#  'நிலைய': 49,
#  'நிகழ்ச்சித்திட்ட': 1,
#  'ஏற்றுக்கொள்ளப்பட்டு': 1,
#  'குருவிட்ட': 1,
#  'பிரிவின்': 252,
#  '2014.09.15': 2,
#  'கிளிநொச்சி': 6,
#  'உருவாக்கப்பட்டது': 1,
#  'கஹடகஸ்திகிலிய': 1,
#  'உறுப்பினர்களின்': 17,
#  'மட்டத்தை': 2,
#  'வளப்படுத்தல்': 2,
#  'அடிப்படை': 35,
#  'கலந்துரையாடல்': 13,
#  '2014.02.18': 1,
#  '2014.02.28': 2,
#  '-': 4307,
#  '2014.03.02': 1,
#  'கஹட்டகஸ்திகிலிய': 1,
#  'இதற்காக': 38,
#  'பிரிவு': 156,
#  '23': 15,
#  '03.2': 1,
#  'ஒருமைப்பாட்டுப்': 3,
#  'அறிமுகம்': 10,
#  'ஒரு': 418,
#  'நாட்டிலே': 1,
#  'வாழுகின்ற': 4,
#  'அனைவரும்': 8,
#  'அந்நாட்டின்': 2,
#  'பிரசைகள்': 1,
#  'எனக்கொண்டு': 1,
#  'வாழ்வதற்கான': 1,
#  'சமூகமொன்றை': 1,
#  'உருவாக்குவதானது': 1,
#  'அபிவிருத்திக்கு': 35,
#  'பெரிதும்': 20,
#  'உதவும்': 3,
#  'அதாவது': 29,
#  'தெளிவான': 2,
#  'ஒன்றினுள்': 2,
#  'செயலாற்றுதல்': 1,
#  'வேண்டும்': 1018,
#  'மட்டத்திலான': 11,
#  'பங்கேற்பு': 9,
#  'வாரத்தின்': 3,
#  'முக்கிய': 14,
#  'திட்டங்களில்': 12,
#  'ஒன்றாகும்': 4,
#  'ஊழியப்': 1,
#  'பங்களிப்பினைப்': 2,
#  'முன்பள்ளிகள்': 1,
#  'பூங்காக்கள்': 1,
#  'சுகநல': 1,
#  'முதியோர்': 37,
#  'இல்லங்கள்': 13,
#  'பகல்': 11,
#  'நேர': 23,
#  'பராமரிப்பு': 26,
#  'ஜனசமூக': 1,
#  'நிலையங்களை': 6,
#  'புனரமைத்தல்': 2,
#  'குடிநீர்': 2,
#  'வசதிகளை': 34,
#  'ஒழுங்கு': 64,
#  'செய்தல்': 166,
#  'பாலங்கள்': 1,
#  'வீதிகள்': 7,
#  'பாடசாலைக்': 20,
#  'கட்டடங்களை': 2,
#  'உள்ளிட்ட': 37,
#  'அத்தியாவசிய': 10,
#  'உட்கட்டமைப்பு': 10,
#  'வசதிகள்': 50,
#  'ஆண்டிலே': 10,
#  'இவ்வாறான': 9,
#  'இரண்டு': 101,
#  'வீதம்': 38,
#  '46': 3,
#  'மேற்கொள்ளப்பட்டுள்ளன': 5,
#  'திட்டத்தின்': 53,
#  'புனரமைப்புச்': 3,
#  'முன்பள்ளி': 7,
#  'நாடளாவிய': 10,
#  'ரீதியில்': 32,
#  'நடாத்தப்பட்ட': 10,
#  'தரம்': 37,
#  '5': 150,
#  'புலமைப்': 8,
#  'பரிசில்': 7,
#  'பரீட்சை': 71,
#  'திட்டமானது': 3,
#  'மற்றுமொரு': 5,
#  'பரீட்சைக்குத்': 4,
#  'தயாராகும்': 1,
#  'மாணவர்களின்': 29,
#  'வினா': 2,
#  'விடை': 3,
#  'பற்றி': 107,
#  'கலந்துரையாடுவதற்கும்': 1,
#  'பதில்': 53,
#  'எழுதும்': 3,
#  'முன்னாயத்தப்': 1,
#  'ஒன்றினை': 42,
#  'வழங்குவதற்கும்': 3,
#  'எடுக்கப்பட்டது': 1,
#  'இந்நிகழ்ச்சித்': 3,
#  'அமுல்படுத்தப்பட்டது': 1,
#  'மொழியிலும்': 3,
#  'நடாத்தப்பட்டன': 3,
#  '16': 34,
#  '620': 1,
#  'மாணவர்கள்': 31,
#  'இதன்': 84,
#  'நன்மையடைந்துள்ளனர்': 2,
#  'வாரத்தை': 4,
#  'முன்னிட்டு': 18,
#  'சங்கங்களை': 3,
#  'தொடர்புபடுத்திக்': 2,
#  'அமுல்படுத்தப்பட்டன': 1,
#  'பல்லின': 2,
#  'பல்சமய': 1,
#  'நானாவித': 3,
#  'நிலைகளிலுள்ள': 1,
#  'நாடான': 2,
#  'இந்நாட்டிலே': 1,
#  'அமைதியாகவும்': 1,
#  'ஒற்றுமையாகவும்': 1,
#  'ஒருவருக்கொருவர்': 1,
#  'மதிப்பளித்து': 2,
#  'துரித': 3,
#  'அபிவிருத்தியினை': 1,
#  'நோக்கி': 6,
#  'பயணிக்கும்': 5,
#  'நாடாக': 2,
#  'மாற்றியமைக்கும்': 1,
#  'நோக்குடன்': 4,
#  'மென்மேலும்': 2,
#  'பல': 35,
#  'விடயங்களை': 13,
#  'உள்ளடக்கி': 6,
#  'எதிர்வரும்': 14,
#  'ஆண்டிலும்': 11,
#  'அமுல்படுத்துவதற்கு': 3,
#  'எதிர்பார்க்கப்படுகின்றது': 3,
#  'இந்நிலையினைப்': 1,
#  'புரிந்துகொண்டு': 1,
#  'பல்வேறு': 52,
#  'இனக்': 1,
#  'குழுக்கள்': 6,
#  'இனங்கள்': 1,
#  'கலாசாரங்களுக்கு': 1,
#  'இடையிலான': 3,
#  'நட்பினை': 1,
#  'உறுதிப்படுத்தி': 4,
#  'சமூகத்தின்': 5,
#  'சகவாழ்வு': 4,
#  'நிலைத்திருக்கும்': 1,
#  'தன்மை': 13,
#  'என்பவற்றிற்கு': 3,
#  'பாதிப்பு': 5,
#  'ஏற்படாதவாறு': 2,
#  'ஒற்றுமைக்கான': 1,
#  'கலந்துரையாடலொன்று': 2,
#  'ஏற்படுத்தப்பட': 1,
#  'வேண்டுமென': 55,
#  'வலியுறுத்தப்படுகின்றது': 1,
#  'பிரகாரம்': 67,
#  'மக்களிடையே': 3,
#  'தொடர்பினை': 3,
#  'கட்டியெழுப்பிக்': 1,
#  'வசதியளிக்கப்படுவதுடன்': 1,
#  'பற்றிய': 207,
#  'செய்தியை': 1,
#  'நாட்டின்': 11,
#  'அனைத்துப்': 6,
#  'பிரதேசங்களுக்கும்': 1,
#  'செல்வதற்கும்': 4,
#  'ஏற்பட்டது': 1,
#  'மாநாட்டினை': 1,
#  'கட்டுரை': 1,
#  'சித்திரப்': 1,
#  'போட்டியொன்றும்': 1,
#  'இப்போட்டியானது': 1,
#  'மட்டத்திலும்': 2,
#  'அகில': 12,
#  'நடாத்தப்பட்டது': 16,
#  'இடத்தில்': 17,
#  'அனைத்துச்': 3,
#  'சேவைகளையும்': 4,
#  'மக்களுக்குத்': 1,
#  'தடையின்றி': 1,
#  'கொள்வதற்குத்': 5,
#  'வசதிகளும்': 3,
#  'வழங்கப்பட்டுள்ளதுடன்': 5,
#  'அனைத்தும்': 5,
#  'இலவசமாக': 16,
#  'பெற்றுக்கொடுக்கப்படுகின்றன': 3,
#  'உதாரணமாக': 7,
#  'அடையாள': 62,
#  'அட்டைக்குத்': 1,
#  'புகைப்படங்கள்': 2,
#  'முத்திரைகள்': 2,
#  'பிறப்புச்': 27,
#  'சான்றிதழ்': 79,
#  'விவாகச்': 1,
#  'மரண': 12,
#  'என்பவற்றிற்காக': 4,
#  'அறவிடப்படுகின்ற': 3,
#  'கட்டணங்கள்': 44,
#  'விவாகங்களுடன்': 1,
#  'தொடர்படைய': 1,
#  'என்பனவும்': 1,
#  'நபர்களிடம்': 1,
#  'எதுவிட': 1,
#  'கட்டமுமின்றி': 1,
#  'மக்களுக்குக்': 10,
#  'காலம்': 108,
#  'சிரமம்': 2,
#  'என்பன': 48,
#  'மீதப்படுத்தப்படுவதுடன்': 1,
#  'பிரசை': 1,
#  'ஒருவர்': 232,
#  'என்ற': 107,
#  'ஆளடையாளத்தை': 1,
#  'உறுதிப்படுத்திக்': 8,
#  'கொள்வதற்கான': 15,
#  'ஆவணமான': 1,
#  'அட்டையினைப்': 1,
#  'பெற்றுக்கொள்வதற்கு': 15,
#  'ஏற்படுவதன்': 1,
#  'அவர்கள்': 77,
#  'சமூகமயப்படுத்தப்படுகின்றனர்': 1,
#  'கொடுத்தல்': 46,
#  'கடந்து': 4,
#  'பிறப்பினை': 1,
#  'பதிதல்': 4,
#  'திருத்தங்கள்': 11,
#  'அன்னளவான': 1,
#  'வயதுச்': 2,
#  'ஆண்டிற்கு': 4,
#  'சுமாராக': 1,
#  '6229': 1,
#  'பேருக்கு': 5,
#  'மேற்படி': 475,
#  'ஆவணங்கள்': 44,
#  'கொடுக்கப்பட்டுள்ளன': 3,
#  'விவாகங்களை': 1,
#  'செய்து': 156,
#  'மாத்திரம்': 55,
#  'விவாகமாகாது': 1,
#  'ஒன்றாக': 8,
#  'வாழ்க்கை': 8,
#  'நடாத்தும்': 3,
#  'நபர்கள்': 9,
#  '413': 1,
#  'விவாகப்': 2,
#  'பதிவு': 84,
#  'வைக்கப்பட்டது': 6,
#  'காணாமற்போன': 3,
#  'அட்டைகளுக்காக': 2,
#  'சான்றிதழ்களை': 2,
#  'அறிக்கைகள்': 29,
#  'சுமார்': 21,
#  'நடமாடும்': 4,
#  'முக்கியமாக': 1,
#  'வடக்கு': 30,
#  'மாகாணங்கள்': 2,
#  'தோட்டப்புற': 1,
#  'பிரதேசங்கள்': 5,
#  'பின்தங்கிய': 2,
#  'உள்ளடக்கப்படும்': 6,
#  'நடாத்தப்பட்டுள்ளன': 2,
#  'முகாம்': 6,
#  'இனங்களைச்': 1,
#  'சேர்ந்த': 30,
#  'இளைஞர்களிடையே': 1,
#  'ஒருமைப்பாட்டினை': 3,
#  'அடிப்படையாகக்': 15,
#  'இணக்கப்பாட்டினை': 1,
#  'ஏற்படுத்துவதன்': 1,
#  'இதய': 3,
#  'சுத்தியுடன்': 2,
#  'கூடிய': 125,
#  'இளம்': 2,
#  'சமூதாயம்': 1,
#  'உருவாக்குவதே': 2,
#  'முகாமின்': 1,
#  'நோக்கமாகும்': 10,
#  'சமுதாயத்தினர்': 1,
#  'எதிர்காலத்தைப்': 1,
#  'பொறுப்பேற்பதற்கும்': 1,
#  'சமூகத்திலே': 2,
#  'மாற்றமொன்றினை': 1,
#  'ஏற்படுத்துவதற்கான': 1,
#  'செயற்பாட்டிலே': 1,
#  'முன்னணி': 2,
#  'வகிக்கக்': 1,
#  'குழுவொன்றாக': 1,
#  'புரிந்து': 1,
#  'அமைச்சினால்': 24,
#  'ஒவ்வொரு': 93,
#  'நடாத்தப்படுகின்றது': 1,
#  'ஓர்': 75,
#  'முகாம்கள்': 2,
#  '04': 91,
#  'நடாத்தப்படுவதுடன்': 2,
#  'முகாமிலே': 1,
#  'முஸ்லிம்': 19,
#  'இனங்களை': 2,
#  'பிரதிநிதித்துவப்படுத்தக்': 1,
#  'கூடியவாறு': 3,
#  '18': 31,
#  'வயதிற்கும்': 2,
#  '30': 63,
#  'இடைப்பட்ட': 2,
#  'யுவதிகள்': 7,
#  '100': 16,
#  '–': 48,
#  '150': 11,
#  'இடைப்பட்டவர்கள்': 1,
#  'பங்கேற்கச்': 2,
#  'செய்யப்பட்டனர்': 2,
#  'மொனராகலை': 3,
#  'நுவரெலியா': 5,
#  'மாவட்டங்களில்': 8,
#  'வருகின்ற': 33,
#  'யுவதிகளுக்கு': 6,
#  'அதிகாரசபையானது': 1,
#  'வழிகாட்டல்': 23,
#  'சேவையின்': 55,
#  'அவர்களுக்குக்': 2,
#  'காணப்படுகின்ற': 24,
#  'பயிற்சிகள்': 7,
#  'அதனூடாக': 7,
#  'ஏற்படுகின்ற': 19,
#  'வாய்ப்புக்கள்': 3,
#  'விளக்கத்தினையும்': 1,
#  'வாய்ப்பினையும்': 2,
#  'எடுக்கப்பட்டுள்ளது': 6,
#  'பெற்றோரை': 3,
#  'இழந்த': 3,
#  'பொறுப்புதாரர்': 2,
#  'பிள்ளைகளுக்கான': 1,
#  'கொள்கையின்': 2,
#  'இலக்காக': 3,
#  'அமைவது': 7,
#  'கல்விக்கான': 2,
#  'நுழைவாகும்': 1,
#  'துறைசார்ந்துள்ள': 1,
#  'குழுக்களைச்': 1,
#  'பிள்ளைகளின்': 17,
#  'நுழைவிற்கு': 1,
#  'வசதியளிக்கும்': 1,
#  'பொருட்டு': 59,
#  'அல்லது': 994,
#  'பிள்ளைகளுக்கு': 2,
#  'உபகரணங்களைப்': 4,
#  'கொடுக்கும்': 18,
#  'திட்டமொன்று': 3,
#  'எமது': 49,
#  'மேற்கொள்ளப்பட்டது': 6,
#  'பெண்கள்': 6,
#  'நிறைவேற்றுகின்ற': 3,
#  'பணியினைப்': 2,
#  'பலப்படுத்துவதற்காக': 1,
#  'அவர்களை': 7,
#  'ஒருமைப்பாட்டிற்காக': 2,
#  'வலுவூட்டும்': 2,
#  'தலைவிகளை': 1,
#  'கண்காணிப்பின்': 5,
#  'கீழுள்ள': 13,
#  'திட்டத்துடன்': 2,
#  'மகளிர்': 52,
#  'அமைச்சும்': 3,
#  'இணைந்து': 17,
#  'நிவாரண': 12,
#  'சுற்றுப்': 2,
#  'பயணம்': 29,
#  'கூட்டங்களை': 2,
#  'என்பவற்றின்': 12,
#  'செயல்': 13,
#  'முறையில்': 64,
#  'அமுல்படுத்துவது': 2,
#  'இலகுவாக்கப்பட்டது': 1,
#  'கலாசார': 15,
#  'சமய': 16,
#  'விழாக்கள்': 1,
#  'சமூகங்கள்': 1,
#  'வாழும்': 9,
#  'இலங்கையினுள்': 2,
#  'சிங்களவர்': 1,
#  'தமிழர்': 1,
#  'முஸ்லிம்கள்': 1,
#  'இனத்தவர்கள்': 1,
#  'வாழ்ந்து': 1,
#  'வருகின்றனர்': 1,
#  'இனங்களுக்கு': 1,
#  'ஏற்ப': 94,
#  'அவர்களது': 13,
#  'சமயம்': 1,
#  ...}

# %%
# Sort the dictionary by value (i.e., by frequency) in descending order
word_freq = {k: v for k, v in sorted(word_freq.items(), key=lambda item: item[1], reverse=True)}

# %%
# Write the results to a CSV file
with open('Frq_2.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    # Write the header row
    writer.writerow(['Word', 'Freq'])
    # Write each word-frequency pair to a separate row
    for word, freq in word_freq.items():
        writer.writerow([word, freq])

# %%
# Create a dictionary to store the frequency of frequencies
freq_freq = {}

# %%
# Count the frequency of each frequency
for freq in word_freq.values():
    freq_freq[freq] = freq_freq.get(freq, 0) + 1

# %%
# Sort the dictionary by value (i.e., by frequency) in descending order
freq_freq = {k: v for k, v in sorted(freq_freq.items(), key=lambda item: item[1], reverse=True)}

# %%
# Write the results to a CSV file
with open('FrFr_2.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    # Write the header row
    writer.writerow(['Freq', 'FreqOfFreq'])
    # Write each frequency-frequency pair to a separate row
    for freq, freq_of_freq in freq_freq.items():
        writer.writerow([freq, freq_of_freq])

# %%
# Sort the word frequencies in descending order
sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)

# %%
# Assign ranks to each word based on its frequency
ranks = {}
rank = 1
prev_freq = None
for word, freq in sorted_word_freq:
    if freq != prev_freq:
        rank = len(word_freq) - sorted_word_freq.index((word, freq))
        prev_freq = freq
    ranks[word] = rank

# %%
# Write the results to a CSV file
with open('Rank_2.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    # Write the header row
    writer.writerow(['Word', 'Freq', 'Rank'])
    # Write each word-frequency-rank triple to a separate row
    for word, freq in sorted_word_freq:
        rank = ranks[word]
        writer.writerow([word, freq, rank])

# %%
import matplotlib.pyplot as plt
import csv

# Create lists to store the word frequencies and ranks
word_freq = []
ranks = []

# Read in the CSV file containing the word frequencies and ranks
with open('Rank_2.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        word_freq.append(int(row['Freq']))
        ranks.append(int(row['Rank']))

# Plot the rank vs frequency graph
plt.scatter(ranks, word_freq)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.title('Zipf\'s Law')
plt.grid(True)

# Save the graph to a PNG file
plt.savefig('Graph_2.png')

# %%
import csv
import math

# Read in the CSV file containing the word frequencies
with open('Frq_2.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    word_freq = {row['Word']: int(row['Freq']) for row in reader}

# Calculate the mean and standard deviation of the word frequencies
freq_values = list(word_freq.values())
mean_freq = sum(freq_values) / len(freq_values)
stddev_freq = math.sqrt(sum([(f - mean_freq)**2 for f in freq_values]) / len(freq_values))

# Calculate the z-score of each word frequency and store it in a new dictionary
word_zscores = {}
for word, freq in word_freq.items():
    z = (freq - mean_freq) / stddev_freq
    word_zscores[word] = z

# Write the results to a CSV file
with open('Z_2.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    # Write the header row
    writer.writerow(['Word', 'Freq', 'Z'])
    # Write each word-frequency-zscore triple to a separate row
    for word, freq in word_freq.items():
        zscore = word_zscores[word]
        writer.writerow([word, freq, zscore])

# %%
import csv

# Set the z-score threshold for stop words
z_threshold = 1.96

# Read in the CSV file containing the z-scores
with open('Z_2.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    word_zscores = {row['Word']: float(row['Z']) for row in reader}

# Identify the stop words based on the z-score threshold
stop_words = [word for word, zscore in word_zscores.items() if zscore >= z_threshold]

# Write the stop words to a text file
with open('Stop_2.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(stop_words))
